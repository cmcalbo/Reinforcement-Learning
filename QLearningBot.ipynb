# %% [markdown]
#    # Q-Learning Trading Bot #

# %% [markdown]
# This notebook is to show the performance of the Q-Learning Trading bot on a portfolio.
#
# The class Q-Trader evaluates the performance between buying and holding S&P 500 and buying Treasury Bills and the performance of the Q-Trader bot trading the S&P calculating and comparing the sharpe ratio of them.
#
# To calculate the sharpe ratio we use the Treasury Bill Rates as risk-free return.

# %%
# We need to import the class qtrader
import qtrader
# %matplotlib notebook

# %%
# We create an object of the class and call the function: graph_portfolio() that compares the different performances
# and displays the results in a figure
q = qtrader.QTrader()
q.graph_portfolio()
# Out:
# For episode 0 we get an internal sharpe ratio of 0.008064074349106994
# For episode 1 we get an internal sharpe ratio of -0.18792068300418485
# For episode 2 we get an internal sharpe ratio of -0.18792068300418485
# For episode 3 we get an internal sharpe ratio of 0.021333388351334838
# For episode 4 we get an internal sharpe ratio of 0.18792068300418485
# For episode 5 we get an internal sharpe ratio of 0.18422319801253553
# For episode 6 we get an internal sharpe ratio of 0.1096463227183514
# For episode 7 we get an internal sharpe ratio of 0.14132399194256257
# For episode 8 we get an internal sharpe ratio of 0.16288466774557572
# For episode 9 we get an internal sharpe ratio of 0.1701328614831444
# For episode 10 we get an internal sharpe ratio of 0.15221170993598382
# For episode 11 we get an internal sharpe ratio of 0.18792068300418485
# For episode 12 we get an internal sharpe ratio of 0.18792068300418485
# For episode 13 we get an internal sharpe ratio of 0.1783035285524487
# ...

# %% [markdown]
# As you can see from the graphic on the horizontal part of the line the bot holds bonds and in the others makes money trading the S&P
#
# Clearly the bot beats the sharpe ratio of buy and holding and the its make a big difference on the drawdown of february 2020.
